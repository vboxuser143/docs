# %% [markdown]
# <a href="https://colab.research.google.com/github/vboxuser143/docs/blob/main/Copy_of_Priya_sonwalkarMBIipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load data
iris = load_iris()

# Convert to DataFrame
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['Target'] = iris.target
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# 1. What is the distribution of sepal length across the dataset?
# 2. What is the average petal width for each species?
# 3. Is there a correlation between sepal length and sepal width?
# 4. Which species has the largest average petal length?
# 5. Are there any outliers in petal width?
# 6. How do the distributions of petal length compare across species?
# 7. What is the standard deviation of each feature (sepal length, petal length, etc.)?
# 8. Are sepal dimensions sufficient to distinguish species visually?
# 9. Can we create a pair plot to observe relationships between all variables?
# 10. What are the min, max, and mean values for each feature?
# 11. Are there any missing values in the dataset?
# 12. Does petal length increase with petal width?
# 13. Which species has the smallest average sepal width?
# 14. Are the measurements linearly separable by species?
# 15. What are the species-wise means and variances?
# 16. How balanced is the dataset in terms of species count?
# 17. What is the shape of the dataset (rows, columns)?
# 18. Are there any duplicate rows in the dataset?
# 19. Are there any clusters visible in the feature space?
# 20. What is the median value of each feature for each species?
